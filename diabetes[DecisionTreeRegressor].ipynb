# %% [markdown]
# <a href="https://colab.research.google.com/github/jhk990602/datapractice/blob/main/diabetes%5BDecisionTreeRegressor%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 데이터셋 출처
# * [Pima Indians Diabetes Database | Kaggle](https://www.kaggle.com/uciml/pima-indians-diabetes-database)
# * https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_diabetes.html
#
#
# ### 데이터 구성
#
# * Pregnancies : 임신 횟수
# * Glucose : 2시간 동안의 경구 포도당 내성 검사에서 혈장 포도당 농도
# * BloodPressure : 이완기 혈압 (mm Hg)
# * SkinThickness : 삼두근 피부 주름 두께 (mm), 체지방을 추정하는데 사용되는 값
# * Insulin : 2시간 혈청 인슐린 (mu U / ml)
# * BMI : 체질량 지수 (체중kg / 키(m)^2)
# * DiabetesPedigreeFunction : 당뇨병 혈통 기능
# * Age : 나이
# * Outcome : 768개 중에 268개의 결과 클래스 변수(0 또는 1)는 1이고 나머지는 0입니다.
#
#
# ## 필요한 라이브러리 로드

# %%
# 데이터 분석을 위한 pandas, 수치계산을 위한 numpy
# 시각화를 위한 seaborn, matplotlib.pyplot 을 로드합니다.

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## 데이터셋 로드

# %%
df = pd.read_csv("/content/drive/MyDrive/boostcourse_data/diabetes.csv")
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## 학습, 예측 데이터셋 나누기

# %%
# label 값을 기준으로 나눕니다.
# 나누기 전에 label 값을 시각화 합니다.
(df['Insulin']>0).value_counts()
# Out:
# True     394
# False    374
# Name: Insulin, dtype: int64

# %%
# train 세트를 만듭니다.

train = df[df['Insulin']>0].copy()
train.shape
# Out:
# (394, 9)

# %%
# test 세트를 만듭니다.

test= df[df['Insulin']==0].copy()
test.shape
# Out:
# (374, 9)

# %% [markdown]
# ##EDA

# %%
sns.displot(train['Insulin'])

# %%
sns.boxplot(x=train['Insulin'])
# Out:
# <Axes: xlabel='Insulin'>

# %%
desc= train['Insulin'].describe()
desc
# Out:
# count    394.000000
# mean     155.548223
# std      118.775855
# min       14.000000
# 25%       76.250000
# 50%      125.000000
# 75%      190.000000
# max      846.000000
# Name: Insulin, dtype: float64

# %%
#IQR : 3IQR - 1IQR
#OUT > 3IQR + (IQR * 1.5)
IQR = desc.loc['75%']- desc.loc['25%']
OUT = desc.loc['75%'] +(IQR * 1.5)

# %%
train[train['Insulin']>OUT].shape
# Out:
# (24, 9)

# %%
print(train.shape)
train = train[train['Insulin']<OUT]
train.shape
# Out:
# (390, 9)
# (370, 9)

# %% [markdown]
# ## 학습, 예측에 사용할 컬럼

# %%
# feature_names 라는 변수에 학습과 예측에 사용할 컬럼명을 가져옵니다.
feature_names= train.columns.tolist()
feature_names.remove('Insulin')
feature_names
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %% [markdown]
# ## 정답값이자 예측해야 될 값

# %%
# label_name 이라는 변수에 예측할 컬럼의 이름을 담습니다.

label_name = 'Insulin'
label_name
# Out:
# 'Insulin'

# %% [markdown]
# ## 학습, 예측 데이터셋 만들기

# %%
# 학습 세트 만들기 예) 시험의 기출문제
X_train = train[feature_names]
X_train.shape
# Out:
# (370, 8)

# %%
# 정답 값을 만들어 줍니다. 예) 기출문제의 정답
y_train= train[label_name]
y_train.shape
# Out:
# (370,)

# %%
# 예측에 사용할 데이터세트를 만듭니다. 예) 실전 시험 문제

X_test = test[feature_names]
X_test.shape
# Out:
# (374, 8)

# %%
# 예측의 정답값 예) 실전 시험 문제의 정답
y_test = test[label_name]
y_test.shape
# Out:
# (374,)

# %% [markdown]
# ## 머신러닝 알고리즘 가져오기

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state= 42)
model
# Out:
# DecisionTreeRegressor(random_state=42)

# %% [markdown]
# ## 학습(훈련)
# * 시험을 볼 때 기출문제(X_train)와 정답(y_train)을 보고 공부하는 과정과 유사합니다.

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %% [markdown]
# ## cross validation 으로 학습 세트의 오차 측정하기

# %%
from sklearn.model_selection import cross_val_predict

y_predict = cross_val_predict(model, X_train,y_train, cv=5, verbose=2,n_jobs=-1)
y_predict
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.1s finished
# array([ 25., 182.,  55., 144., 220.,  83., 176., 310.,  90., 120.,  56.,
#         29., 120.,  25., 130., 190., 105., 207.,  90., 265.,  59., 285.,
#        168., 231.,  78., 105., 170.,  44., 168.,  99., 160.,  61., 115.,
#         82.,  18., 231., 230.,  57.,  96., 180.,  15., 165.,  14., 115.,
#        170., 130.,  66.,  74., 168.,  32., 194.,  58.,  14.,  82.,  54.,
#        140.,  71., 165., 144., 293.,  49., 125., 105., 178.,  18., 165.,
#        105., 135.,  14., 150., 100., 100.,  25., 140., 191., 150.,  87.,
#        110., 140.,  66.,  49.,  70., 145.,  82.,  49., 167., 152., 175.,
#        230., 210., 182., 207., 105.,  49., 105., 325., 115., 250.,  74.,
#        144., 207., 115., 140.,  70.,  56., 120.,  43.,  37., 180., 210.,
#        158., 145.,  40., 180., 171., 274., 190., 120.,  60., 230.,  82.,
#        182., 130., 166.,  22., 150.,  86., 191., 125., 176., 168., 204.,
#        140., 127., 176.,  90., 175.,  48.,  74., 175., 291., 171., 171.,
#         82., 183.,  50.,  63.,  74., 285., 135., 155., 318.,  92., 220.,
#        135.,  16.,  56., 130., 165., 183.,  50., 105., 210.,  44.,  15.,
#        176.,  67.,  96., 168., 126.,  54.,  23.,  79., 105., 125.,  94.,
#        176., 300.,  50.,  48., 115., 205., 278.,  23., 182., 105., 300.,
#         71.,  90.,  48., 205.,  94., 228.,  63., 100., 293., 291., 159.,
#         79., 235.,  71., 178., 168., 228.,  90., 272., 215.,  57.,  57.,
#         77.,  94., 120.,  50.,  50., 129., 165.,  15.,  18., 160., 106.,
#        125., 190.,  87.,  48.,  87.,  76., 210., 185.,  64., 182.,  60.,
#        194.,  18.,  66., 194., 190.,  43., 180.,  57., 128., 175., 110.,
#        196., 180., 231.,  76., 231.,  76., 194., 240., 140.,  45.,  77.,
#         49.,  78.,  63., 106.,  59.,  48., 182.,  75.,  67., 205.,  55.,
#         59., 210., 240., 140., 325.,  71.,  50.,  59.,  94., 325.,  43.,
#         90.,  94.,  92., 190., 293.,  96., 106., 160., 175., 335., 182.,
#        194., 160.,  76., 114., 159.,  76.,  48., 240., 185.,  38., 194.,
#         48.,  48., 150., 100., 155.,  76., 140.,  18.,  77.,  82., 360.,
#         92.,  18., 125.,  78.,  70.,  96., 284., 360.,  88., 196., 230.,
#         64.,  71., 105.,  56., 255., 237., 176., 126., 318., 150.,  18.,
#        130.,  36.,  66.,  72., 166.,  64., 146., 210., 108., 105., 180.,
#        205., 125., 140.,  36., 122., 105., 171.,  94., 176., 126., 135.,
#        176., 140., 140.,  44., 360.,  84., 220.,  94.,  48., 100.,  78.,
#         48., 192., 130., 108.,  60., 110., 115.])

# %%
# 정답을 정확하게 맞춘 갯수
(y_predict == y_train).sum()
# Out:
# 7

# %%
len(y_train)
# Out:
# 370

# %%
# regplot 으로 결과 값을 비교합니다.

sns.regplot(x=y_train,y=y_predict)
# Out:
# <Axes: xlabel='Insulin'>

# %%
# r2_score 를 구합니다.

from sklearn.metrics import r2_score
r2_score(y_train,y_predict)
# Out:
# -0.28551906710833275

# %%
# distplot으로 정답값과 예측값의 분포를 그립니다.

sns.distplot(y_train, hist=False, label="train")
sns.distplot(y_predict, hist=False, label="predict")
# Out:
# <ipython-input-58-13543c6b0a72>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train, hist=False, label="train")
# <ipython-input-58-13543c6b0a72>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_predict, hist=False, label="predict")
# <Axes: xlabel='Insulin', ylabel='Density'>

# %% [markdown]
# ## 오차 구하기

# %%
# MAE
#86
#77.55 (Insulin<600)
#62.05 (Insulin<OUT)
error = abs(y_train-y_predict)
error.mean()
# Out:
# 62.056756756756755

# %%
# sns.distplot(error)
sns.displot(error, kde=True)

# %%
error.describe()
# Out:
# count    370.000000
# mean      62.056757
# std       56.854443
# min        0.000000
# 25%       19.250000
# 50%       42.500000
# 75%       89.750000
# max      307.000000
# Name: Insulin, dtype: float64

# %%
# RMSE
#126.895
#114.077 (Insulin<600)
#84.111 (Insulin<OUT)
np.sqrt(((y_train-y_predict)**2).mean())
# Out:
# 84.11142866717003

# %% [markdown]
# ## 트리 알고리즘 분석하기
# * 의사결정나무를 시각화 합니다.
# * 피처의 중요도를 구합니다.

# %%
# plot_tree로 시각화 하기

plt.figure(figsize=(20,20))
from sklearn.tree import plot_tree
tree=plot_tree(model,
          feature_names= feature_names,
          filled=True,
          fontsize=10)

# %%
# 피처의 중요도를 추출하기
model.feature_importances_
# Out:
# array([0.04858345, 0.44656558, 0.07097731, 0.05588694, 0.16087336,
#        0.09607089, 0.11025783, 0.01078464])

# %%
# 피처의 중요도 시각화 하기
sns.barplot(x=model.feature_importances_, y=feature_names)
# Out:
# <Axes: >

# %% [markdown]
# ## 예측
# * 실전 시험문제(X_test)라고 보면 됩니다. 우리가 정답을 직접 예측합니다.
# * Insulin 이 0인 값을 예측 했기 때문에 정답을 알 수 없습니다.
# * 따라서 점수는 train set로 측정한 값을 참고합니다.

# %%
y_test = model.predict(X_test)
y_test[:5]
# Out:
# array([168.,  37., 130., 215., 165.])

# %%
train.groupby('Outcome')['Insulin'].describe()
# Out:
#          count        mean        std   min     25%    50%     75%    max
# Outcome
# 0        254.0  115.917323  69.844697  15.0   64.25  100.0  151.00  342.0
# 1        116.0  169.163793  70.789454  14.0  124.25  160.0  207.75  360.0

# %%
test["Insulin"] = y_test

# %%
test.groupby("Outcome")["Insulin"].describe()
# Out:
#          count        mean        std   min    25%    50%    75%    max
# Outcome
# 0        236.0  124.906780  80.878263  18.0  64.00   97.5  155.0  335.0
# 1        138.0  163.724638  83.718835  14.0  96.75  145.0  215.0  328.0

# %%
# Insulin 평균값을 출력
sns.barplot(data=train, x='Outcome',y='Insulin')
# Out:
# <Axes: xlabel='Outcome', ylabel='Insulin'>

# %%
# 예측값
sns.barplot(data=test, x="Outcome", y="Insulin")
# Out:
# <Axes: xlabel='Outcome', ylabel='Insulin'>
